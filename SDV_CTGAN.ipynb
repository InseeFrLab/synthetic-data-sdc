# %%
from sdv.datasets.demo import download_demo

real_data, metadata = download_demo(
    modality='single_table',
    dataset_name='fake_hotel_guests'
)

# %%
real_data.head()
# Out:
#                guest_email  has_rewards room_type  amenities_fee checkin_date  \
# 0  michaelsanders@shaw.net        False     BASIC          37.89  27 Dec 2020
# 1        randy49@brown.biz        False     BASIC          24.37  30 Dec 2020
# 2    webermelissa@neal.com         True    DELUXE           0.00  17 Sep 2020
# 3          gsims@terry.com        False     BASIC            NaN  28 Dec 2020
# 4        misty33@smith.biz        False     BASIC          16.45  05 Apr 2020
#
#   checkout_date  room_rate                                    billing_address  \
# 0   29 Dec 2020     131.23        49380 Rivers Street\nSpencerville, AK 68265
# 1   02 Jan 2021     114.43          88394 Boyle Meadows\nConleyberg, TN 22063
# 2   18 Sep 2020     368.33  0323 Lisa Station Apt. 208\nPort Thomas, LA 82585
# 3   31 Dec 2020     115.61          77 Massachusetts Ave\nCambridge, MA 02139
# 4           NaN     122.41             1234 Corporate Drive\nBoston, MA 02116
#
#     credit_card_number
# 0  4075084747483975747
# 1      180072822063468
# 2       38983476971380
# 3     4969551998845740
# 4     3558512986488983

# %% [markdown]
# ### Fonction permettant de connaître les modalités de chaques variables

# %%
import numpy as np
import pandas as pd

def get_statistics(dataframe):
    stats_list = []
    
    for column in dataframe.columns:
        if np.issubdtype(dataframe[column].dtype, np.number):
            stats = {
                'variable': column,
                'min': dataframe[column].min(),
                'max': dataframe[column].max(),
                'mediane': dataframe[column].median(),
                'moyenne': dataframe[column].mean(),
                'std': dataframe[column].std(),
                'cv': dataframe[column].std() / dataframe[column].mean() if dataframe[column].mean() != 0 else np.nan,
                'q025': dataframe[column].quantile(0.025),
                'q1': dataframe[column].quantile(0.25),
                'q3': dataframe[column].quantile(0.75),
                'q975': dataframe[column].quantile(0.975)
            }
        else:
            value_counts = dataframe[column].value_counts()
            stats = {
                'variable': column,
                'nb_modalites': value_counts.size,
                'plus_freq': value_counts.idxmax(),
                'plus_freq_eff': value_counts.max(),
                'moins_freq': value_counts.idxmin(),
                'moins_freq_eff': value_counts.min()
            }
        
        stats_list.append(stats)
    
    stats_df = pd.DataFrame(stats_list)
    return stats_df

# %%
get_statistics(real_data)
# Out:
#              variable  nb_modalites  \
# 0         guest_email         500.0
# 1         has_rewards           2.0
# 2           room_type           3.0
# 3       amenities_fee           NaN
# 4        checkin_date         265.0
# 5       checkout_date         275.0
# 6           room_rate           NaN
# 7     billing_address         230.0
# 8  credit_card_number           NaN
#
#                                    plus_freq  plus_freq_eff  \
# 0                    danieltaylor@harper.com            1.0
# 1                                      False          447.0
# 2                                      BASIC          384.0
# 3                                        NaN            NaN
# 4                                13 Oct 2020            7.0
# 5                                15 Oct 2020            5.0
# 6                                        NaN            NaN
# 7  77 Massachusetts Ave\nCambridge, MA 02139           53.0
# 8                                        NaN            NaN
#
#                                        moins_freq  moins_freq_eff  \
# 0                         danieltaylor@harper.com             1.0
# 1                                            True            53.0
# 2                                           SUITE            38.0
# 3                                             NaN             NaN
# 4                                     22 Mar 2020             1.0
# 5                                     25 Mar 2020             1.0
# 6                                             NaN             NaN
# 7  06567 John Walk Apt. 238\nWest Scott, NV 61617             1.0
# 8                                             NaN             NaN
#
#             min           max       mediane       moyenne           std  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3  0.000000e+00  4.812000e+01  1.859000e+01  1.817607e+01  1.101881e+01
# 4           NaN           NaN           NaN           NaN           NaN
# 5           NaN           NaN           NaN           NaN           NaN
# 6  8.380000e+01  4.248400e+02  1.301100e+02  1.525894e+02  5.630475e+01
# 7           NaN           NaN           NaN           NaN           NaN
# 8  5.018004e+11  4.985421e+18  2.384672e+15  4.330974e+17  1.312004e+18
#
#          cv          q025            q1            q3          q975
# 0       NaN           NaN           NaN           NaN           NaN
# 1       NaN           NaN           NaN           NaN           NaN
# 2       NaN           NaN           NaN           NaN           NaN
# 3  0.606226  0.000000e+00  1.042000e+01  2.557000e+01  3.860650e+01
# 4       NaN           NaN           NaN           NaN           NaN
# 5       NaN           NaN           NaN           NaN           NaN
# 6  0.368995  1.015665e+02  1.128925e+02  1.808875e+02  2.948355e+02
# 7       NaN           NaN           NaN           NaN           NaN
# 8  3.029351  5.634406e+11  3.045467e+13  4.509813e+15  4.642584e+18

# %% [markdown]
# ## Création du synthétiseur

# %%
from sdv.single_table import CTGANSynthesizer

synthesizer = CTGANSynthesizer(metadata)
synthesizer.fit(real_data)

# %% [markdown]
# ## Génération des données synthétiques

# %%
synthetic_data = synthesizer.sample(num_rows = 500)
synthetic_data.head()
# Out:
#                      guest_email  has_rewards room_type  amenities_fee  \
# 0           tsanchez@example.com        False    DELUXE           0.00
# 1          bellshawn@example.com        False    DELUXE           2.93
# 2             iwhite@example.org        False     BASIC          15.02
# 3  christophermiller@example.com        False     SUITE          13.73
# 4            dgarcia@example.org         True    DELUXE          11.12
#
#   checkin_date checkout_date  room_rate  \
# 0  05 Jan 2020   07 Jan 2020     251.74
# 1  04 Nov 2020   01 Mar 2020     304.38
# 2  21 Oct 2020   07 Jul 2020     156.19
# 3  14 Mar 2020   10 Aug 2020     136.59
# 4  05 Jan 2020   08 Mar 2020     135.03
#
#                                     billing_address  credit_card_number
# 0        52424 Ashley Ridges\nLake Daniel, MP 27650    3582077138450885
# 1        18561 Thomas Canyon\nJoshuamouth, SD 22073    4142271383722418
# 2          78944 Marie Harbor\nCynthiaton, IA 56020    6573028438398211
# 3  47551 Hall Flats Apt. 315\nSouth James, WA 16993      30343480880655
# 4      38378 Nicholas Mount\nWest Michael, CO 91475       4930915359735

# %%
get_statistics(synthetic_data)
# Out:
#              variable  nb_modalites  \
# 0         guest_email         500.0
# 1         has_rewards           2.0
# 2           room_type           3.0
# 3       amenities_fee           NaN
# 4        checkin_date         249.0
# 5       checkout_date         230.0
# 6           room_rate           NaN
# 7     billing_address         500.0
# 8  credit_card_number           NaN
#
#                                    plus_freq  plus_freq_eff  \
# 0                    randallcruz@example.net            1.0
# 1                                      False          355.0
# 2                                      BASIC          259.0
# 3                                        NaN            NaN
# 4                                05 Jan 2020           63.0
# 5                                07 Jan 2020           85.0
# 6                                        NaN            NaN
# 7  61298 Gibson Manor\nHannahville, FM 54615            1.0
# 8                                        NaN            NaN
#
#                                   moins_freq  moins_freq_eff           min  \
# 0                    randallcruz@example.net             1.0           NaN
# 1                                       True           145.0           NaN
# 2                                      SUITE           103.0           NaN
# 3                                        NaN             NaN  0.000000e+00
# 4                                03 Mar 2020             1.0           NaN
# 5                                17 Jan 2020             1.0           NaN
# 6                                        NaN             NaN  8.380000e+01
# 7  61298 Gibson Manor\nHannahville, FM 54615             1.0           NaN
# 8                                        NaN             NaN  6.043246e+10
#
#             max       mediane       moyenne           std        cv  \
# 0           NaN           NaN           NaN           NaN       NaN
# 1           NaN           NaN           NaN           NaN       NaN
# 2           NaN           NaN           NaN           NaN       NaN
# 3  4.812000e+01  3.460000e+00  7.860763e+00  9.856661e+00  1.253906
# 4           NaN           NaN           NaN           NaN       NaN
# 5           NaN           NaN           NaN           NaN       NaN
# 6  4.248400e+02  1.513650e+02  1.802010e+02  6.774494e+01  0.375941
# 7           NaN           NaN           NaN           NaN       NaN
# 8  4.984532e+18  3.539338e+15  3.882559e+17  1.276814e+18  3.288589
#
#            q025            q1            q3          q975
# 0           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN
# 3  0.000000e+00  0.000000e+00  1.336500e+01  3.264950e+01
# 4           NaN           NaN           NaN           NaN
# 5           NaN           NaN           NaN           NaN
# 6  1.035455e+02  1.352100e+02  2.263750e+02  3.562062e+02
# 7           NaN           NaN           NaN           NaN
# 8  5.703557e+11  1.800412e+14  4.902626e+15  4.768220e+18

# %% [markdown]
# Sur cette simple synthétisation, on constate que le synthétiseur ne crée pas de valeurs numériques en dehors de l'étendue originale.

# %% [markdown]
# ## Diagnostique

# %% [markdown]
# ### Risque

# %%
from sdv.evaluation.single_table import run_diagnostic

diagnostic = run_diagnostic(
    real_data = real_data,
    synthetic_data = synthetic_data,
    metadata = metadata
)
# Out:
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 9/9 [00:00<00:00, 935.07it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 420.02it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%

# %% [markdown]
# ### Utilité

# %%
from sdv.evaluation.single_table import evaluate_quality

quality_report = evaluate_quality(
    real_data,
    synthetic_data,
    metadata
)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 9/9 [00:00<00:00, 903.34it/s]|
# Column Shapes Score: 72.53%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 36/36 [00:00<00:00, 231.14it/s]|
# Column Pair Trends Score: 72.95%
#
# Overall Score (Average): 72.74%

# %% [markdown]
# ## Graphiques

# %%
from sdv.evaluation.single_table import get_column_plot

fig = get_column_plot(
    real_data = real_data,
    synthetic_data = synthetic_data,
    column_name = 'room_type',
    metadata = metadata
)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_100.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
